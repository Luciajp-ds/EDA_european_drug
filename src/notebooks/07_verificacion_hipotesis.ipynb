# %% [markdown]
# En este notebook se incluye:
#
# 1. ¿Se cumplieron vuestras hipótesis iniciales?
# 2. ¿Descubristeis algo diferente o inesperado?
# 3. ¿Qué insights principales habéis obtenido?
# 4. Documentad tanto los hallazgos esperados como los sorprendentes
